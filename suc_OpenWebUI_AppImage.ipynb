# %%
# !git clone https://github.com/open-webui/desktop.git
# Out:
# Cloning into 'desktop'...
# remote: Enumerating objects: 1321, done.
# remote: Counting objects: 100% (219/219), done.
# remote: Compressing objects: 100% (151/151), done.
# remote: Total 1321 (delta 69), reused 68 (delta 68), pack-reused 1102 (from 3)
# Receiving objects: 100% (1321/1321), 14.52 MiB | 15.60 MiB/s, done.
# Resolving deltas: 100% (578/578), done.

# %%
# %cd /content/desktop
# Out:
# /content/desktop

# %%
# !npm install
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴npm warn deprecated rimraf@3.0.2: Rimraf versions prior to v4 are no longer supported
# ⠴⠦⠧⠇npm warn deprecated npmlog@6.0.2: This package is no longer supported.
# ⠇⠏⠋⠙⠹npm warn deprecated lodash.isequal@4.5.0: This package is deprecated. Use require('node:util').isDeepStrictEqual instead.
# ⠹⠸⠼⠴⠦npm warn deprecated glob@7.2.3: Glob versions prior to v9 are no longer supported
# ⠧⠇⠏⠋⠙⠹npm warn deprecated gauge@4.0.4: This package is no longer supported.
# ⠹npm warn deprecated are-we-there-yet@3.0.1: This package is no longer supported.
# ⠹⠸⠼⠴⠦npm warn deprecated boolean@3.2.0: Package no longer supported. Contact Support at https://www.npmjs.com/support for more info.
# ⠦⠧⠇npm warn deprecated @npmcli/move-file@2.0.1: This functionality has been moved to @npmcli/fs
# ⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼npm warn deprecated glob@8.1.0: Glob versions prior to v9 are no longer supported
# ...

# %%
# !npm run build:linux
# Out:
# > open-webui-desktop@0.0.1 build:linux
# > npm run build && electron-builder --linux
#
#
# > open-webui-desktop@0.0.1 build
# > npm run typecheck && electron-vite build
#
#
# > open-webui-desktop@0.0.1 typecheck
# > npm run typecheck:node && npm run svelte-check
#
#
# > open-webui-desktop@0.0.1 typecheck:node
# > tsc --noEmit -p tsconfig.node.json --composite false
#
# ⠙
# > open-webui-desktop@0.0.1 svelte-check
# > svelte-check --tsconfig ./tsconfig.json
#
# Loading svelte-check in workspace: /content/desktop
# Getting Svelte diagnostics...
#
# svelte-check found 0 errors and 0 warnings
# ⠙⠙vite v7.0.6 building SSR bundle for production...
# ✓ 4 modules transformed.
# out/main/index.js  34.63 kB
# ✓ built in 428ms
# vite v7.0.6 building SSR bundle for production...
# ✓ 1 modules transformed.
# out/preload/index.js  5.06 kB
# ✓ built in 54ms
# vite v7.0.6 building for production...
# ...

# %% [markdown]
# https://github.com/open-webui/desktop

# %%
# !npm run dev
# Out:
# > open-webui-desktop@0.0.1 dev
# > electron-vite dev
#
# vite v7.0.6 building SSR bundle for development...
# ✓ 4 modules transformed.
# out/main/index.js  34.63 kB
# ✓ built in 301ms
#
# build the electron main process successfully
#
# -----
#
# vite v7.0.6 building SSR bundle for development...
# ✓ 1 modules transformed.
# out/preload/index.js  5.06 kB
# ✓ built in 66ms
#
# build the electron preload files successfully
#
# -----
#
# 10:34:05 PM [vite] (client) Forced re-optimization of dependencies
#
# dev server running for the electron renderer process at:
#
#   ➜  Local:   http://localhost:5173/
#   ➜  Network: use --host to expose
#
# start electron app...
#
# /content/desktop/node_modules/electron/dist/electron: error while loading shared libraries: libatk-1.0.so.0: cannot open shared object file: No such file or directory
# ⠙

# %%
/content/desktop/dist/open-webui-desktop-0.0.1.AppImage

# %%
/content/desktop/dist/open-webui-desktop_0.0.1_amd64.deb

# %%
/content/desktop/dist/open-webui-desktop_0.0.1_amd64.snap
